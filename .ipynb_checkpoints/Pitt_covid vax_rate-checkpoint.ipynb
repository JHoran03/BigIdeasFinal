# %%
import pandas as pd

covid = pd.read_csv("covid_vax_municipal.csv")
covid. head()
# Out:
#         neighborhood_municipality total_partially_vaccinated  \
# 0     Allegheny West (Pittsburgh)                     14.25%
# 1          Arlington (Pittsburgh)                      7.17%
# 2  Arlington Heights (Pittsburgh)                      0.28%
# 3         Banksville (Pittsburgh)                      9.46%
# 4  Bedford Dwellings (Pittsburgh)                      9.12%
#
#   total_fully_vaccinated total_fully_vaccinated_w_booster  total_population
# 0                 42.52%                           44.42%               421
# 1                 31.46%                           18.30%              1869
# 2                  1.01%                            0.30%              6331
# 3                 42.27%                           35.73%              3818
# 4                 27.52%                           12.02%              1348

# %%
covid.sort_values(["total_fully_vaccinated_w_booster","total_fully_vaccinated","total_partially_vaccinated"], ascending = False)
# Out:
#                  neighborhood_municipality total_partially_vaccinated  \
# 21        Lower Lawrenceville (Pittsburgh)                     13.51%
# 0              Allegheny West (Pittsburgh)                     14.25%
# 18              Highland Park (Pittsburgh)                     13.24%
# 27        Squirrel Hill South (Pittsburgh)                     15.78%
# 8   Central Business District (Pittsburgh)                     27.44%
# 5                  Bloomfield (Pittsburgh)                     12.30%
# 3                  Banksville (Pittsburgh)                      9.46%
# 9           Central Northside (Pittsburgh)                     10.04%
# 12           Duquesne Heights (Pittsburgh)                      9.77%
# 7                   Brookline (Pittsburgh)                      6.92%
# 6                       Bluff (Pittsburgh)                      3.38%
# 26        Squirrel Hill North (Pittsburgh)                     15.20%
# ...

# %% [markdown]
# By reading the table above, we can see that the city "Lower Lawrenceville" is the best city in Pittsburgh, because it has the most number of vaccinated people in pittsburgh, this city is the safest city in pitt.
